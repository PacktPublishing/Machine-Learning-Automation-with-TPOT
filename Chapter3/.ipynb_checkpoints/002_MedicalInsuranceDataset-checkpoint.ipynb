# %% [markdown]
# ## Dataset loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

# %%
df = pd.read_csv('data/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <br><br>
#
# ## Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.figure(figsize=(12, 7))
plt.title('Target variable (charges) distribution', size=20)
plt.xlabel('Charge', size=14)
plt.ylabel('Count', size=14)
plt.hist(df['charges'], bins=15, color='#4f4f4f', ec='#040404');

# %%
def make_bar_chart(column, title, ylabel, xlabel, y_offset=0.12, x_offset=700):
    ax = df.groupby(column).median()[['charges']].plot(
        kind='bar', figsize=(10, 6), fontsize=13, color='#4f4f4f'
    )
    ax.set_title(title, size=20, pad=30)
    ax.set_ylabel(ylabel, fontsize=14)
    ax.set_xlabel(xlabel, fontsize=14)
    ax.get_legend().remove()
                  
    for i in ax.patches:
        ax.text(i.get_x() + x_offset, i.get_height() + y_offset, f'${str(round(i.get_height(), 2))}', fontsize=15)
    return ax

# %%
make_bar_chart(
    column='smoker',
    title='Median insurance charges for smokers and non-smokers',
    ylabel='Insurance charge ($)',
    xlabel='Is smoker?',
    y_offset=700,
    x_offset=0.12
)

# %%
make_bar_chart(
    column='sex',
    title='Median insurance charges between genders',
    ylabel='Insurance charge ($)',
    xlabel='Gender',
    y_offset=200,
    x_offset=0.15
)

# %%
make_bar_chart(
    column='children',
    title='Median insurance charges by number of children',
    ylabel='Insurance charge ($)',
    xlabel='Number of children',
    y_offset=200,
    x_offset=-0.15
)

# %%
make_bar_chart(
    column='region',
    title='Median insurance charges by region',
    ylabel='Insurance charge ($)',
    xlabel='Region',
    y_offset=200,
    x_offset=0
)

# %% [markdown]
# <br><br>
#
# ## Data Preparation

# %%
df['sex'] = [1 if x == 'female' else 0 for x in df['sex']]
df.rename(columns={'sex': 'is_female'}, inplace=True)

df['smoker'] = [1 if x == 'yes' else 0 for x in df['smoker']]

region_dummies = pd.get_dummies(df['region'], drop_first=True, prefix='region')

df = pd.concat([region_dummies, df], axis=1)
df.drop('region', axis=1, inplace=True)

df.head()
# Out:
#    region_northwest  region_southeast  region_southwest  age  is_female  \
# 0                 0                 0                 1   19          1
# 1                 0                 1                 0   18          0
# 2                 0                 1                 0   28          0
# 3                 1                 0                 0   33          0
# 4                 1                 0                 0   32          0
#
#       bmi  children  smoker      charges
# 0  27.900         0       1  16884.92400
# 1  33.770         1       0   1725.55230
# 2  33.000         3       0   4449.46200
# 3  22.705         0       0  21984.47061
# 4  28.880         0       0   3866.85520

# %%
plt.figure(figsize=(12, 9))
plt.title('Correlation matrix', size=20)
sns.heatmap(df.corr(), annot=True, cmap='Blues');

# %% [markdown]
# <br><br>
#
# ## Modelling

# %%
from sklearn.model_selection import train_test_split

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

y_train.shape, y_test.shape
# Out:
# ((1003,), (335,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

rmse = lambda y, y_hat: np.sqrt(mean_squared_error(y, y_hat))

lm = LinearRegression()
lm.fit(X_train, y_train)

lm_preds = lm.predict(X_test)
print(f'R2   = {r2_score(y_test, lm_preds):.2f}')
print(f'RMSE = {rmse(y_test, lm_preds):.2f}')
# Out:
# R2   = 0.77
# RMSE = 5926.02

# %%
for i, column in enumerate(df.columns[:-1]):
    coef = np.round(lm.coef_[i], 2)
    print(f'{column:17}: {coef:8}')
# Out:
# region_northwest :  -355.15
# region_southeast :  -781.37
# region_southwest :  -860.27
# age              :   259.62
# is_female        :   -45.62
# bmi              :   339.81
# children         :    426.5
# smoker           :  23630.4

# %%
from tpot import TPOTRegressor

pipeline_optimizer = TPOTRegressor(
    scoring='r2',
    max_time_mins=10,
    random_state=42,
    verbosity=2
)

pipeline_optimizer.fit(X_train, y_train)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', style=ProgressStyle(description_w…
# Generation 1 - Current best internal CV score: 0.8506515769036094
#
# Generation 2 - Current best internal CV score: 0.8506515769036094
#
# Generation 3 - Current best internal CV score: 0.8506515769036094
#
# Generation 4 - Current best internal CV score: 0.8506515769036094
#
# Generation 5 - Current best internal CV score: 0.8508015012639911
#
# Generation 6 - Current best internal CV score: 0.854533334580158
#
# Generation 7 - Current best internal CV score: 0.854533334580158
#
# 10.01 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: ExtraTreesRegressor(GradientBoostingRegressor(DecisionTreeRegressor(input_matrix, max_depth=2, min_samples_leaf=16, min_samples_split=9), alpha=0.75, learning_rate=1.0, loss=huber, max_depth=2, max_features=0.7500000000000001, min_samples_leaf=5, min_samples_split=16, n_estimators=100, subsample=0.7500000000000001), bootstrap=False, max_features=0.8, min_samples_leaf=11, min_samples_split=20, n_estimators=100)
# TPOTRegressor(max_time_mins=10, random_state=42, scoring='r2', verbosity=2)

# %%
pipeline_optimizer.score(X_test, y_test)
# Out:
# 0.8626764480217046

# %%
tpot_preds = pipeline_optimizer.predict(X_test)

print(f'R2   = {r2_score(y_test, tpot_preds):.2f}')
print(f'RMSE = {rmse(y_test, tpot_preds):.2f}')
# Out:
# R2   = 0.86
# RMSE = 4552.02

# %%
pipeline_optimizer.fitted_pipeline_
# Out:
# Pipeline(steps=[('stackingestimator-1',
#                  StackingEstimator(estimator=DecisionTreeRegressor(max_depth=2,
#                                                                    min_samples_leaf=16,
#                                                                    min_samples_split=9,
#                                                                    random_state=42))),
#                 ('stackingestimator-2',
#                  StackingEstimator(estimator=GradientBoostingRegressor(alpha=0.75,
#                                                                        learning_rate=1.0,
#                                                                        loss='huber',
#                                                                        max_depth=2,
#                                                                        max_features=0.7500000000000001,
#                                                                        min_samples_leaf=5,
#                                                                        min_samples_split=16,
#                                                                        random_state=42,
#                                                                        subsample=0.7500000000000001))),
#                 ('extratreesregressor',
#                  ExtraTreesRegressor(max_features=0.8, min_samples_leaf=11,
#                                      min_samples_split=20, random_state=42))])

# %%
pipeline_optimizer.export('insurance_pipeline.py')
